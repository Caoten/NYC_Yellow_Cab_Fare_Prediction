# %%
import sqlite3
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import folium
import fastparquet
import os

# %% [markdown]
# ### Connect to Database and create Cursor

# %%
path="F:/1_Bachelorarbeit/1_Daten/1_Yellow_Cab_Trips_2009-June_2016/Sqlite/NYC_Yellow_Cab_Tripdata"
# Create Database or if Name is there open Database
connection = sqlite3.connect(path)
# Create Cursor for SQL-Commands
cursor=connection.cursor()

# %% [markdown]
# ### Sample 2.000.000 Random Entries of all Tripdata Tables

# %%
dtypes={"Pickup_DateTime":np.datetime64,"Dropoff_DateTime":np.datetime64,"Passenger_Count":np.uint8,"Trip_Distance":np.float16,"Pickup_Lon":np.float32,"Pickup_Lat":np.float32,"RateCodeID":np.uint8,"Dropoff_Lon":np.float32,"Dropoff_Lat":np.float32,"Fare_Amt":np.float16}
# Give me 250000 random sample from table tripdata_2009
sql = "SELECT * FROM tripdata_2009 ORDER BY RANDOM() LIMIT 250000;"  
df_origin = pd.read_sql_query(sql, connection, index_col="Trip_ID")
# Replace all None Values of RateCodeID with Zero -> Because 0 is for none RateCodeID
df_origin["RateCodeID"].fillna(value=0, inplace=True)

# %%
df_origin
# Out:
#                Pickup_DateTime     Dropoff_DateTime  Passenger_Count  \
# Trip_ID
# 56172835   2009-05-04 00:45:40  2009-05-04 00:49:59                1
# 168340108  2009-12-18 19:11:35  2009-12-18 20:05:53                1
# 113884629  2009-09-10 23:43:00  2009-09-10 23:55:00                5
# 71547033   2009-06-15 20:59:00  2009-06-15 21:07:00                1
# 113147745  2009-09-16 15:30:20  2009-09-16 15:58:29                1
# 132261594  2009-10-12 12:16:00  2009-10-12 12:27:00                2
# 47465336   2009-04-19 12:33:56  2009-04-19 12:48:56                3
# 136761581  2009-10-19 08:09:02  2009-10-19 08:26:46                1
# 78761008   2009-06-20 17:35:00  2009-06-20 17:44:00                1
# 133601321  2009-10-07 08:13:51  2009-10-07 08:29:59                2
# 128148469  2009-10-09 18:29:00  2009-10-09 18:45:00                1
# 137853977  2009-10-22 19:23:00  2009-10-22 19:27:00                1
# ...

# %%
# Give me 250000 random sample from table tripdata_2010
sql = "SELECT * FROM tripdata_2010 ORDER BY RANDOM() LIMIT 250000;"  
df_append = pd.read_sql_query(sql, connection,index_col="Trip_ID")
df_origin=df_origin.append(df_append,ignore_index=True)
df_origin
# Out:
#             Pickup_DateTime     Dropoff_DateTime  Passenger_Count  \
# 0       2009-05-04 00:45:40  2009-05-04 00:49:59                1
# 1       2009-12-18 19:11:35  2009-12-18 20:05:53                1
# 2       2009-09-10 23:43:00  2009-09-10 23:55:00                5
# 3       2009-06-15 20:59:00  2009-06-15 21:07:00                1
# 4       2009-09-16 15:30:20  2009-09-16 15:58:29                1
# 5       2009-10-12 12:16:00  2009-10-12 12:27:00                2
# 6       2009-04-19 12:33:56  2009-04-19 12:48:56                3
# 7       2009-10-19 08:09:02  2009-10-19 08:26:46                1
# 8       2009-06-20 17:35:00  2009-06-20 17:44:00                1
# 9       2009-10-07 08:13:51  2009-10-07 08:29:59                2
# 10      2009-10-09 18:29:00  2009-10-09 18:45:00                1
# 11      2009-10-22 19:23:00  2009-10-22 19:27:00                1
# 12      2009-03-08 02:13:59  2009-03-08 02:22:45                2
# ...

# %%
# Give me 250000 random sample from table tripdata_2011
sql = "SELECT * FROM tripdata_2011 ORDER BY RANDOM() LIMIT 250000;"  
df_append = pd.read_sql_query(sql, connection,index_col="Trip_ID")
df_origin=df_origin.append(df_append,ignore_index=True)
df_origin
# Out:
#             Pickup_DateTime     Dropoff_DateTime  Passenger_Count  \
# 0       2009-05-04 00:45:40  2009-05-04 00:49:59                1
# 1       2009-12-18 19:11:35  2009-12-18 20:05:53                1
# 2       2009-09-10 23:43:00  2009-09-10 23:55:00                5
# 3       2009-06-15 20:59:00  2009-06-15 21:07:00                1
# 4       2009-09-16 15:30:20  2009-09-16 15:58:29                1
# 5       2009-10-12 12:16:00  2009-10-12 12:27:00                2
# 6       2009-04-19 12:33:56  2009-04-19 12:48:56                3
# 7       2009-10-19 08:09:02  2009-10-19 08:26:46                1
# 8       2009-06-20 17:35:00  2009-06-20 17:44:00                1
# 9       2009-10-07 08:13:51  2009-10-07 08:29:59                2
# 10      2009-10-09 18:29:00  2009-10-09 18:45:00                1
# 11      2009-10-22 19:23:00  2009-10-22 19:27:00                1
# 12      2009-03-08 02:13:59  2009-03-08 02:22:45                2
# ...

# %%
# Give me 250000 random sample from table tripdata_2012
sql = "SELECT * FROM tripdata_2012 ORDER BY RANDOM() LIMIT 250000;"  
df_append = pd.read_sql_query(sql, connection,index_col="Trip_ID")
df_origin=df_origin.append(df_append,ignore_index=True)
df_origin
# Out:
#             Pickup_DateTime     Dropoff_DateTime  Passenger_Count  \
# 0       2009-05-04 00:45:40  2009-05-04 00:49:59                1
# 1       2009-12-18 19:11:35  2009-12-18 20:05:53                1
# 2       2009-09-10 23:43:00  2009-09-10 23:55:00                5
# 3       2009-06-15 20:59:00  2009-06-15 21:07:00                1
# 4       2009-09-16 15:30:20  2009-09-16 15:58:29                1
# 5       2009-10-12 12:16:00  2009-10-12 12:27:00                2
# 6       2009-04-19 12:33:56  2009-04-19 12:48:56                3
# 7       2009-10-19 08:09:02  2009-10-19 08:26:46                1
# 8       2009-06-20 17:35:00  2009-06-20 17:44:00                1
# 9       2009-10-07 08:13:51  2009-10-07 08:29:59                2
# 10      2009-10-09 18:29:00  2009-10-09 18:45:00                1
# 11      2009-10-22 19:23:00  2009-10-22 19:27:00                1
# 12      2009-03-08 02:13:59  2009-03-08 02:22:45                2
# ...

# %%
# Give me 250000 random sample from table tripdata_2013
sql = "SELECT * FROM tripdata_2013 ORDER BY RANDOM() LIMIT 250000;"  
df_append = pd.read_sql_query(sql, connection,index_col="Trip_ID")
df_origin=df_origin.append(df_append,ignore_index=True)
df_origin
# Out:
#              Pickup_DateTime     Dropoff_DateTime  Passenger_Count  \
# 0        2009-05-04 00:45:40  2009-05-04 00:49:59                1
# 1        2009-12-18 19:11:35  2009-12-18 20:05:53                1
# 2        2009-09-10 23:43:00  2009-09-10 23:55:00                5
# 3        2009-06-15 20:59:00  2009-06-15 21:07:00                1
# 4        2009-09-16 15:30:20  2009-09-16 15:58:29                1
# 5        2009-10-12 12:16:00  2009-10-12 12:27:00                2
# 6        2009-04-19 12:33:56  2009-04-19 12:48:56                3
# 7        2009-10-19 08:09:02  2009-10-19 08:26:46                1
# 8        2009-06-20 17:35:00  2009-06-20 17:44:00                1
# 9        2009-10-07 08:13:51  2009-10-07 08:29:59                2
# 10       2009-10-09 18:29:00  2009-10-09 18:45:00                1
# 11       2009-10-22 19:23:00  2009-10-22 19:27:00                1
# 12       2009-03-08 02:13:59  2009-03-08 02:22:45                2
# ...

# %%
# Give me 250000 random sample from table tripdata_2014
sql = "SELECT * FROM tripdata_2014 ORDER BY RANDOM() LIMIT 250000;"  
df_append = pd.read_sql_query(sql, connection,index_col="Trip_ID")
df_origin=df_origin.append(df_append,ignore_index=True)
df_origin
# Out:
#              Pickup_DateTime     Dropoff_DateTime  Passenger_Count  \
# 0        2009-05-04 00:45:40  2009-05-04 00:49:59                1
# 1        2009-12-18 19:11:35  2009-12-18 20:05:53                1
# 2        2009-09-10 23:43:00  2009-09-10 23:55:00                5
# 3        2009-06-15 20:59:00  2009-06-15 21:07:00                1
# 4        2009-09-16 15:30:20  2009-09-16 15:58:29                1
# 5        2009-10-12 12:16:00  2009-10-12 12:27:00                2
# 6        2009-04-19 12:33:56  2009-04-19 12:48:56                3
# 7        2009-10-19 08:09:02  2009-10-19 08:26:46                1
# 8        2009-06-20 17:35:00  2009-06-20 17:44:00                1
# 9        2009-10-07 08:13:51  2009-10-07 08:29:59                2
# 10       2009-10-09 18:29:00  2009-10-09 18:45:00                1
# 11       2009-10-22 19:23:00  2009-10-22 19:27:00                1
# 12       2009-03-08 02:13:59  2009-03-08 02:22:45                2
# ...

# %%
# Give me 250000 random sample from table tripdata_2015
sql = "SELECT * FROM tripdata_2015 ORDER BY RANDOM() LIMIT 250000;"  
df_append = pd.read_sql_query(sql, connection,index_col="Trip_ID")
df_origin=df_origin.append(df_append,ignore_index=True)
df_origin
# Out:
#              Pickup_DateTime     Dropoff_DateTime  Passenger_Count  \
# 0        2009-05-04 00:45:40  2009-05-04 00:49:59                1
# 1        2009-12-18 19:11:35  2009-12-18 20:05:53                1
# 2        2009-09-10 23:43:00  2009-09-10 23:55:00                5
# 3        2009-06-15 20:59:00  2009-06-15 21:07:00                1
# 4        2009-09-16 15:30:20  2009-09-16 15:58:29                1
# 5        2009-10-12 12:16:00  2009-10-12 12:27:00                2
# 6        2009-04-19 12:33:56  2009-04-19 12:48:56                3
# 7        2009-10-19 08:09:02  2009-10-19 08:26:46                1
# 8        2009-06-20 17:35:00  2009-06-20 17:44:00                1
# 9        2009-10-07 08:13:51  2009-10-07 08:29:59                2
# 10       2009-10-09 18:29:00  2009-10-09 18:45:00                1
# 11       2009-10-22 19:23:00  2009-10-22 19:27:00                1
# 12       2009-03-08 02:13:59  2009-03-08 02:22:45                2
# ...

# %%
# Give me 250000 random sample from table tripdata_2016
sql = "SELECT * FROM tripdata_2016 ORDER BY RANDOM() LIMIT 250000;"  
df_append = pd.read_sql_query(sql, connection,index_col="Trip_ID")
df_origin=df_origin.append(df_append,ignore_index=True)
df_origin
# Out:
#              Pickup_DateTime     Dropoff_DateTime  Passenger_Count  \
# 0        2009-05-04 00:45:40  2009-05-04 00:49:59                1
# 1        2009-12-18 19:11:35  2009-12-18 20:05:53                1
# 2        2009-09-10 23:43:00  2009-09-10 23:55:00                5
# 3        2009-06-15 20:59:00  2009-06-15 21:07:00                1
# 4        2009-09-16 15:30:20  2009-09-16 15:58:29                1
# 5        2009-10-12 12:16:00  2009-10-12 12:27:00                2
# 6        2009-04-19 12:33:56  2009-04-19 12:48:56                3
# 7        2009-10-19 08:09:02  2009-10-19 08:26:46                1
# 8        2009-06-20 17:35:00  2009-06-20 17:44:00                1
# 9        2009-10-07 08:13:51  2009-10-07 08:29:59                2
# 10       2009-10-09 18:29:00  2009-10-09 18:45:00                1
# 11       2009-10-22 19:23:00  2009-10-22 19:27:00                1
# 12       2009-03-08 02:13:59  2009-03-08 02:22:45                2
# ...

# %%
#Convert the dtypes of each Column for Exploration
df_origin= df_origin.astype(dtypes)

# %%
df_origin.dtypes
# Out:
# Pickup_DateTime     datetime64[ns]
# Dropoff_DateTime    datetime64[ns]
# Passenger_Count              uint8
# Trip_Distance              float16
# Pickup_Lon                 float32
# Pickup_Lat                 float32
# RateCodeID                   uint8
# Dropoff_Lon                float32
# Dropoff_Lat                float32
# Fare_Amt                   float16
# dtype: object

# %%
df_origin.describe()
# Out:
#        Passenger_Count  Trip_Distance    Pickup_Lon    Pickup_Lat  \
# count     2.000000e+06   2.000000e+06  2.000000e+06  2.000000e+06
# mean      1.680213e+00            NaN -7.259229e+01  3.997297e+01
# std       1.332114e+00            NaN  1.148459e+01  8.268709e+00
# min       0.000000e+00   0.000000e+00 -3.356731e+03 -3.432144e+03
# 25%       1.000000e+00   1.000000e+00 -7.399200e+01  4.073510e+01
# 50%       1.000000e+00   1.740234e+00 -7.398174e+01  4.075274e+01
# 75%       2.000000e+00   3.160156e+00 -7.396694e+01  4.076726e+01
# max       2.080000e+02            inf  2.478932e+03  3.210374e+03
#
#          RateCodeID   Dropoff_Lon   Dropoff_Lat      Fare_Amt
# count  2.000000e+06  1.999988e+06  1.999988e+06  2.000000e+06
# mean   9.086285e-01 -7.260003e+01  3.997572e+01           NaN
# std    6.849591e-01  1.166386e+01  8.923161e+00           NaN
# min    0.000000e+00 -2.928909e+03 -3.485255e+03 -2.900000e+02
# ...

# %%
# Convert to parquet for quick reloading
# Set Path for Parquet Files
path="F:/1_Bachelorarbeit/1_Daten/1_Yellow_Cab_Trips_2009-June_2016/Dataset_for_Exploration"
df_origin.to_parquet(os.path.join(path, "Exploration_Data" + "." + "parquet"),engine="fastparquet")
