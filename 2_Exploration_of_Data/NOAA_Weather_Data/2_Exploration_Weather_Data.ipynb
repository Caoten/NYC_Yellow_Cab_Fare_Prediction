# %%
import pandas as pd
import datetime as dt
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import os
# %matplotlib inline
pd.set_option('display.max_columns', None)

# %%
path="F:/1_Bachelorarbeit/1_Daten/1_Yellow_Cab_Trips_2009-June_2016/5_Dataset_for_Exploration/Exploration_Weather_Data.csv"
dtypes={"AWND":np.float16,"PRCP":np.float16,"SNOW":np.float16,"SNWD":np.float16,"TAVG":np.float16,"TMAX":np.float16,"TMIN":np.float16}
df_weather_origin = pd.read_csv(path,dtype=dtypes,parse_dates=["DATE"])

# %%
df_weather_origin.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2738 entries, 0 to 2737
# Data columns (total 25 columns):
# DATE    2738 non-null datetime64[ns]
# AWND    2708 non-null float16
# PRCP    2738 non-null float16
# SNOW    2738 non-null float16
# SNWD    2738 non-null float16
# TAVG    0 non-null float16
# TMAX    2738 non-null float16
# TMIN    2738 non-null float16
# WT01    2738 non-null bool
# WT02    2738 non-null bool
# WT03    2738 non-null bool
# WT04    2738 non-null bool
# WT05    2738 non-null bool
# WT06    2738 non-null bool
# WT07    2738 non-null bool
# WT08    2738 non-null bool
# WT09    2738 non-null bool
# WT11    2738 non-null bool
# WT13    2738 non-null bool
# WT14    2738 non-null bool
# WT16    2738 non-null bool
# WT17    2738 non-null bool
# WT18    2738 non-null bool
# WT19    2738 non-null bool
# WT22    2738 non-null bool
# dtypes: bool(17), datetime64[ns](1), float16(7)
# memory usage: 104.4 KB

# %%
df_weather_origin
# Out:
#            DATE       AWND      PRCP      SNOW  SNWD  TAVG  TMAX  TMIN   WT01  \
# 0    2009-01-01  11.179688  0.000000  0.000000   0.0   NaN  26.0  15.0  False
# 1    2009-01-02   6.261719  0.000000  0.000000   0.0   NaN  34.0  23.0  False
# 2    2009-01-03  10.070312  0.000000  0.000000   0.0   NaN  38.0  29.0  False
# 3    2009-01-04   7.609375  0.000000  0.000000   0.0   NaN  42.0  25.0  False
# 4    2009-01-05   6.929688  0.000000  0.000000   0.0   NaN  43.0  38.0  False
# 5    2009-01-06   6.710938  0.080017  0.000000   0.0   NaN  38.0  31.0   True
# 6    2009-01-07  10.507812  1.190430  0.000000   0.0   NaN  38.0  31.0   True
# 7    2009-01-08  11.406250  0.000000  0.000000   0.0   NaN  38.0  29.0  False
# 8    2009-01-09   9.617188  0.000000  0.000000   0.0   NaN  32.0  26.0  False
# 9    2009-01-10   6.710938  0.140015  1.000000   0.0   NaN  30.0  23.0   True
# 10   2009-01-11   6.929688  0.189941  0.000000   1.0   NaN  31.0  24.0   True
# ...

# %%
df_weather_origin.describe()
# Out:
#               AWND         PRCP         SNOW         SNWD  TAVG         TMAX  \
# count  2708.000000  2738.000000  2738.000000  2738.000000   0.0  2738.000000
# mean      5.691406     0.136353     0.112854     0.642090   NaN          inf
# std       2.490234     0.391846     0.944336     2.580078   NaN    18.390625
# min       0.219971     0.000000     0.000000     0.000000   NaN    15.000000
# 25%       3.800781     0.000000     0.000000     0.000000   NaN    48.000000
# 50%       5.140625     0.000000     0.000000     0.000000   NaN    64.000000
# 75%       6.929688     0.049988     0.000000     0.000000   NaN    79.000000
# max      22.812500     5.808594    27.296875    23.000000   NaN   104.000000
#
#               TMIN
# count  2738.000000
# mean           inf
# std      16.734375
# min      -1.000000
# 25%      36.000000
# 50%      49.000000
# 75%      63.000000
# max      84.000000

# %% [markdown]
# #### Observation:
# #### 1. TAVG have just NaN Values
# #### 1. 30 Missing Values for Average daily Wind Speed
# #### 2. TMAX and TMIN are in Fahrenheit
# #### 3. PRCP and SNOW and SNWD are in inches
# #### 4. AWND is in Miles per Hour

# %% [markdown]
# ### Delete Column TAVG

# %%
df_weather_origin.drop(columns=["TAVG"], inplace=True)

# %% [markdown]
# ### Checking if there are any NaN Values in the Columns

# %%
df_weather_origin.isnull().sum()
# Out:
# DATE     0
# AWND    30
# PRCP     0
# SNOW     0
# SNWD     0
# TMAX     0
# TMIN     0
# WT01     0
# WT02     0
# WT03     0
# WT04     0
# WT05     0
# WT06     0
# WT07     0
# WT08     0
# WT09     0
# WT11     0
# WT13     0
# WT14     0
# WT16     0
# WT17     0
# WT18     0
# WT19     0
# WT22     0
# dtype: int64

# %%
num_entries=len(df_weather_origin)
percent=(df_weather_origin["AWND"].isnull().sum() / num_entries)*100
print(str(percent) + "%")
# Out:
# 1.095690284879474%

# %%
# Check the NaN Values of Drop-offs
df_weather_origin.loc[df_weather_origin.isnull().any(axis=1)]
# Out:
#            DATE  AWND      PRCP  SNOW      SNWD  TMAX  TMIN   WT01   WT02  \
# 142  2009-05-23   NaN  0.000000   0.0  0.000000  73.0  60.0  False  False
# 143  2009-05-24   NaN  0.000000   0.0  0.000000  83.0  60.0   True  False
# 144  2009-05-25   NaN  0.000000   0.0  0.000000  81.0  63.0  False  False
# 145  2009-05-26   NaN  0.000000   0.0  0.000000  66.0  53.0  False  False
# 149  2009-05-30   NaN  0.000000   0.0  0.000000  77.0  60.0  False  False
# 150  2009-05-31   NaN  0.000000   0.0  0.000000  81.0  57.0  False  False
# 176  2009-06-26   NaN  0.729980   0.0  0.000000  83.0  64.0   True   True
# 177  2009-06-27   NaN  0.020004   0.0  0.000000  81.0  63.0   True  False
# 178  2009-06-28   NaN  0.000000   0.0  0.000000  82.0  64.0  False  False
# 382  2010-01-18   NaN  0.049988   0.0  0.000000  50.0  37.0   True  False
# 383  2010-01-19   NaN  0.000000   0.0  0.000000  48.0  40.0  False  False
# 389  2010-01-25   NaN  1.250000   0.0  0.000000  57.0  49.0   True   True
# ...

# %% [markdown]
# ### Problem:
# ### 1. Missing Value for AWND (30 Rows)
# ### Solution: Replace NaN with the mean Value of AWND and create Column AWND_DUMMY to mark it as True Value
#
# ![](Weather_Data_missing_value_AWND.jpg)

# %% [markdown]
# ### Replace NaN Values with mean Value and create Column AWND_DUMMY

# %%
df_weather_origin["AWND_DUMMY"]=False
# Replace all NaN with mean Value and set is_dummy to True
df_weather_origin.fillna(value=df_weather_origin["AWND"].mean(),inplace=True)
df_weather_origin.loc[(df_weather_origin["AWND"]==5.69141),["AWND_DUMMY"]]=True

# %%
df_weather_origin.describe()
# Out:
#               AWND         PRCP         SNOW         SNWD         TMAX  \
# count  2738.000000  2738.000000  2738.000000  2738.000000  2738.000000
# mean      5.687500     0.136353     0.112854     0.642090          inf
# std       2.476562     0.391846     0.944336     2.580078    18.390625
# min       0.219971     0.000000     0.000000     0.000000    15.000000
# 25%       3.800781     0.000000     0.000000     0.000000    48.000000
# 50%       5.371094     0.000000     0.000000     0.000000    64.000000
# 75%       6.929688     0.049988     0.000000     0.000000    79.000000
# max      22.812500     5.808594    27.296875    23.000000   104.000000
#
#               TMIN
# count  2738.000000
# mean           inf
# std      16.734375
# min      -1.000000
# 25%      36.000000
# 50%      49.000000
# 75%      63.000000
# max      84.000000

# %% [markdown]
# ### Exploratory Analysis

# %% [markdown]
# ### How is the Distribution of TMAX?

# %%
plt.figure(figsize = (12, 8))
plt.xlabel('TMAX') 
plt.ylabel('Density')
sns.distplot(df_weather_origin["TMAX"]);

# %% [markdown]
# #### Observation
# #### 1. The most max Temperature is in area between 80-90 Fahrenheit

# %% [markdown]
# ### How is the Distribution of TMin?

# %%
plt.figure(figsize = (12, 8))
plt.xlabel('TMIN') 
plt.ylabel('Density')
sns.distplot(df_weather_origin["TMIN"]);

# %% [markdown]
# #### Observation
# #### 1.The most min. Temperature are over 60 Fahrenheit

# %% [markdown]
# ### How is the Distribution of Precipitation?

# %%
plt.figure(figsize = (12, 8))
plt.xlabel('Precipitation') 
plt.ylabel('Density')
sns.distplot(df_weather_origin["PRCP"]);

# %% [markdown]
# #### Observation
# #### 1. The most Precipitation is in area between 0-0.1 inches

# %% [markdown]
# ### How is the Distribution of Averge daily Wind Speed?

# %%
plt.figure(figsize = (12, 8))
plt.xlabel('Average daily Wind Speed') 
plt.ylabel('Density')
sns.distplot(df_weather_origin["AWND"]);

# %% [markdown]
# #### Observation
# #### 1. The most Average Wind Speed are in the Area of 5 Miles per Hour

# %% [markdown]
# ### How is the Distribution of Snow?

# %%
plt.figure(figsize = (12, 8))
plt.xlabel('SNOW') 
plt.ylabel('Density')
sns.distplot(df_weather_origin["SNOW"]);

# %% [markdown]
# #### Observation
# #### 1. The most Snow is in area between 0-0.1 inches

# %% [markdown]
# ### How is the Distribution of SNWD?

# %%
plt.figure(figsize = (12, 8))
plt.xlabel('SNWD') 
plt.ylabel('Density')
sns.distplot(df_weather_origin["SNWD"]);

# %% [markdown]
# #### Observation
# #### 1. The most SNWD is in area between 0-0.1 inches

# %% [markdown]
# ### How does TMAX developed over the Years?

# %%
df_weather_origin["year"]=df_weather_origin["DATE"].dt.year
df_weather_origin.groupby("year")["TMAX"].mean().plot()

# %% [markdown]
# #### Observation:
# #### 1. between 2015-2016 is a strong decrease

# %% [markdown]
# ### How does TMIN developed over the Years?

# %%
df_weather_origin.groupby("year")["TMIN"].mean().plot()

# %% [markdown]
# #### Observation:
# #### 1. in 2015-2016 is a strong decrease

# %% [markdown]
# ### How does TMAX developed over Months?

# %%
df_weather_origin["month"]=df_weather_origin["DATE"].dt.month
df_weather_origin.groupby("month")["TMAX"].mean().plot()

# %% [markdown]
# #### Observation:
# #### 1. Between Month June to August is the highest Temperature

# %% [markdown]
# ### How does TMIN developed over Months?

# %%
df_weather_origin.groupby("month")["TMIN"].mean().plot()

# %% [markdown]
# #### Observation:
# #### 1. Between Month June to August is the highest Temperature

# %% [markdown]
# ### How does the TMAX developed over the years every day?

# %%
df_weather_origin.groupby("DATE")["TMAX"].mean().plot()

# %% [markdown]
# ### How does the TMIN developed over the years every day?

# %%
df_weather_origin.groupby("DATE")["TMIN"].mean().plot()

# %%
df_weather_origin.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2738 entries, 0 to 2737
# Data columns (total 27 columns):
# DATE          2738 non-null datetime64[ns]
# AWND          2738 non-null float16
# PRCP          2738 non-null float16
# SNOW          2738 non-null float16
# SNWD          2738 non-null float16
# TMAX          2738 non-null float16
# TMIN          2738 non-null float16
# WT01          2738 non-null bool
# WT02          2738 non-null bool
# WT03          2738 non-null bool
# WT04          2738 non-null bool
# WT05          2738 non-null bool
# WT06          2738 non-null bool
# WT07          2738 non-null bool
# WT08          2738 non-null bool
# WT09          2738 non-null bool
# WT11          2738 non-null bool
# WT13          2738 non-null bool
# WT14          2738 non-null bool
# WT16          2738 non-null bool
# WT17          2738 non-null bool
# WT18          2738 non-null bool
# WT19          2738 non-null bool
# WT22          2738 non-null bool
# ...

# %%
# Drop Columns
df_weather_origin.drop(columns=["year","month"],inplace=True)

# %%
# Convert to csv File for Exloration
# Set Path for Csv File
path="F:/1_Bachelorarbeit/1_Daten/1_Yellow_Cab_Trips_2009-June_2016/6_Preprocessed_Data/Preprocessed_Weather_Data.csv"
df_weather_origin.to_csv(path,index=False)
