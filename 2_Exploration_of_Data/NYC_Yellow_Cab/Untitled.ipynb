# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import fastparquet
import os
import plotly.express as px
from plotly.offline import iplot
# %matplotlib inline

# %% [markdown]
# ### Read the Parquet File for Data Exploration

# %%
path="F:/1_Bachelorarbeit/1_Daten/1_Yellow_Cab_Trips_2009-June_2016/5_Dataset_for_Exploration/Exploration_Tripdata_2m.parquet"
# Testing the Parquet Files
df=pd.read_parquet(path=path,engine="fastparquet")
df
# Out:
#             Pickup_DateTime    Dropoff_DateTime  Passenger_Count  \
# 0       2009-06-04 22:02:56 2009-06-04 22:11:56                2
# 1       2009-06-06 22:02:00 2009-06-06 22:30:00                1
# 2       2009-06-19 17:01:00 2009-06-19 17:09:00                3
# 3       2009-01-18 19:47:30 2009-01-18 19:53:35                2
# 4       2009-07-13 09:27:47 2009-07-13 09:39:49                1
# 5       2009-09-15 18:12:00 2009-09-15 18:29:00                1
# 6       2009-05-02 20:56:00 2009-05-02 21:06:00                1
# 7       2009-02-14 05:55:48 2009-02-14 06:02:13                1
# 8       2009-07-24 22:29:05 2009-07-24 22:49:13                1
# 9       2009-03-18 09:21:59 2009-03-18 09:39:36                1
# 10      2009-05-12 19:06:29 2009-05-12 19:12:06                4
# 11      2009-10-06 08:35:34 2009-10-06 08:57:34                1
# 12      2009-08-04 15:23:00 2009-08-04 15:36:00                1
# ...

# %%
#extract Year from Datetime Object
df["Pickup_Year"]=df["Pickup_DateTime"].dt.year

# %%
df.loc[(df["Pickup_Year"]==2009),["RateCodeID"]]=np.NaN

# %%
df.describe()
# Out:
#        Passenger_Count  Trip_Distance    Pickup_Lon    Pickup_Lat  \
# count     2.000000e+06   2.000000e+06  2.000000e+06  2.000000e+06
# mean      1.681454e+00            inf -7.257114e+01  3.996286e+01
# std       1.333940e+00            NaN  1.297025e+01  1.086378e+01
# min       0.000000e+00   0.000000e+00 -3.358101e+03 -3.114292e+03
# 25%       1.000000e+00   1.009766e+00 -7.399204e+01  4.073508e+01
# 50%       1.000000e+00   1.730469e+00 -7.398177e+01  4.075269e+01
# 75%       2.000000e+00   3.169922e+00 -7.396697e+01  4.076724e+01
# max       2.080000e+02            inf  3.380714e+03  3.351468e+03
#
#          RateCodeID   Dropoff_Lon   Dropoff_Lat      Fare_Amt   Pickup_Year
# count  1.750000e+06  1.999989e+06  1.999989e+06  2.000000e+06  2.000000e+06
# mean   1.038405e+00 -7.259656e+01  3.997035e+01           inf  2.012500e+03
# std    5.888300e-01  1.306104e+01  1.079283e+01           NaN  2.291288e+00
# ...

# %%
# How many Percent of RateCodeID are NaN
(len(df.loc[df["RateCodeID"].isnull()])/len(df))*100
# Out:
# 12.5

# %%
df.isnull().sum()
# Out:
# Pickup_DateTime          0
# Dropoff_DateTime         0
# Passenger_Count          0
# Trip_Distance            0
# Pickup_Lon               0
# Pickup_Lat               0
# RateCodeID          250000
# Dropoff_Lon             11
# Dropoff_Lat             11
# Fare_Amt                 0
# Pickup_Year              0
# dtype: int64

# %%
(len(df.loc[df["Dropoff_Lon"].isna()])+len(df.loc[df["Dropoff_Lat"].isna()]))/len(df)*100
# Out:
# 0.0011
